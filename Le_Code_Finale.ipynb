# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from pathlib import Path
import numpy as np
import newspaper
from itertools import groupby
from sklearn.feature_extraction.text import TfidfVectorizer
import pickle
import re
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import xgboost as xgb

from sklearn import svm
from sklearn.metrics import classification_report

# %%
with open('Data.pkl', 'rb') as input_file:
    Data = pickle.load(input_file)

# %%
ans = [el for el,_ in groupby(sorted([str(tag) for tag in Data['answer']]))]
Sentences_by_tag = {}
i=0
for Tag in ans:
    Sentences_by_tag[Tag] = i
    i=i+1
Documents = []
for Unique_tag in Sentences_by_tag.keys():
    Sentences_by_tag[Unique_tag] = []
    Sentences = ''
    i = 0
    for tag in Data['answer']:
        if str(tag) == Unique_tag:
            Sentences += ' '
            Sentences += str(Data['sentence'][i])
        i=i+1
    Sentences_by_tag[Unique_tag] = Sentences
    Documents.append(Sentences_by_tag[Unique_tag])

for i in range(len(Documents)):
    Documents[i] = re.sub(r"[\d+_]", "", Documents[i], flags=re.UNICODE)
vectorizer = TfidfVectorizer(lowercase = True, stop_words = stopwords.words('english')) 
matrix = vectorizer.fit_transform(Documents)


Positions = {}
j=0
for word in vectorizer.get_feature_names():
    Positions[word] = j
    j=j+1
amountWords = len(vectorizer.get_feature_names()) 
Tf_idf = pd.DataFrame(matrix.toarray(), columns = Positions.keys(), index = Sentences_by_tag.keys())
Tf_idf
# Out:
#         aaa    aachen     aaron       aas        ab     abadi   abandon  \
# 0  0.001721  0.000484  0.000484  0.003387  0.000484  0.000000  0.002754
# 1  0.001265  0.000000  0.000000  0.000000  0.000000  0.000889  0.001898
#
#    abandoned  abandoning  abandonment  ...  zubaydah    zurdos  zvloqcxl  \
# 0   0.002410    0.000689     0.000689  ...  0.000689  0.000000  0.000484
# 1   0.003795    0.000633     0.001265  ...  0.000633  0.000889  0.000000
#
#    zvolensy  zwerling        ça      être     óscar      über      ülés
# 0  0.000484  0.000484  0.000484  0.000484  0.000484  0.000484  0.000968
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# [2 rows x 17650 columns]

# %%
with open('TF-IDF.pkl', 'wb') as output_file: 
    pickle.dump(Tf_idf, output_file, protocol=pickle.HIGHEST_PROTOCOL)
with open('Positions.pkl', 'wb') as output_file: 
    pickle.dump(Positions, output_file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('TF-IDF.pkl', 'rb') as input_file:
    Tf_idf = pickle.load(input_file)
with open('Positions.pkl', 'rb') as input_file:
    Positions = pickle.load(input_file)

# %%
def normalize(v):
    norm = np.linalg.norm(v)
    if norm == 0: 
        return v
    return v / norm

# %%
#Функция, превращающая предложение в список чисел в соответствии со схемой
def To_vector (Sentence, Positions, Tf_Idf):
    stolbec = np.zeros(len(Positions))
    if isinstance(Sentence, str):
        splittedSentence = re.split(r"[,.!?:;\"\'\(\)\%\=\#\&\@\$\-\*\+\>\<\/\ \s]", Sentence)
        splittedSentence = list(filter(None, splittedSentence)) 
        for word in splittedSentence:
            try:
                position = Positions[word.lower()]
                stolbec[position] += 1
            except KeyError:
                continue
        if len(splittedSentence) > 1:
            for c in range (len(splittedSentence)-1):
                pair = splittedSentence[c] + ' ' + splittedSentence[c+1]
                try:
                    position = Positions[word.lower()]
                    stolbec[position] += 1
                except KeyError:
                    continue
    return(normalize(Tf_Idf.dot(stolbec)))

# %%
#Превращаем тестовую выборку в вектора
def Create_vectors(Some_data, Positions, Tf_Idf):
    Test = []
    j=1
    x = len(Some_data)
    print("Vectorization in progress:")
    for i in Some_data:
        Test.append(To_vector(i, Positions, Tf_Idf))
        line = str(j) + '/' + str(x)
        print(line, end="\r")
        j += 1 
    return(Test)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(Data['sentence'], Data['answer'], test_size=0.15, random_state=42)

# %%
line = []
onesIndex = []
ones = []

# %%
for row in Y_train.keys():
    if Y_train[row] == 1:
        onesIndex.append(row)
        line.append(X_train[row])

# %%
zerData = pd.DataFrame(list(X_train), columns = ['sentence'], index = X_train.keys()).join(pd.DataFrame(list(Y_train), columns = ['answer'], index = Y_train.keys()))
zerData
# Out:
#                                                 sentence  answer
# 1744        How did Warren resolve this troubling issue?       0
# 15532  To deal with the perceived threat the US has d...       0
# 7284   The unnamed US citizen assigned to the consula...       0
# 6388   All presidents since Clinton have crossed coun...       0
# 811    The White House also announced Monday that it ...       0
# 3656   To date, in addition to the three original sig...       0
# 3090   The priest would kiss the boys and grope them,...       0
# 5066                                       Advertisement       0
# 12811  - [And just two days ago, Archbishop Salvatore...       1
# 15458  It’s respecting the diversity that we have in ...       0
# 14951  In a series of tweets on Thursday, President T...       0
# 9045   A Muslima in the U.S. promoted the Islamic Sta...       0
# 16282  That's what Columbia snowflakes thought was of...       1
# 3879   We need the Sacrifice of the Mass – not a meal...       0
# 15842  Democratic party leaders provided staffers wit...       0
# 13096  She noticed that Latino voters did record-brea...       1
# 10241                                   This was unjust.       1
# 15941  This massive Democrat voter fraud could be the...       1
# 9862   No matter your race, creed, ethnicity, sexual ...       0
# 12187  The emerging homosexual clergy scandal is just...       0
# 7889   And Trump is president because he read the par...       1
# 9980   War at the Top of the ... Eric Margolis Best P...       0
# 6550   That said, on average the disease kills around...       0
# 14100  Given that 36 years have passed since the inci...       0
# 15433   Assange never even considered fleeing to Russia.       1
# 15902  Do you agree with the call for a federal inves...       0
# 9214   But what, Mr. Farage, are we to think about th...       1
# 10046  The Byzantine scholar Bessarion wrote to the D...       0
# 8546   It’s the very reason the governments of the wo...       1
# 15849  Despite barbed wires and thousands of troops o...       0
# ...                                                  ...     ...
# 5051   O’Malley, the archbishop of Boston, said in th...       1
# 5311        “I think that was what they wanted to write.       0
# 2433   Gonzalez hails from McAllen, Texas, and attend...       0
# 6949   Keep these facts in mind as we read through th...       0
# 15773  If Congress insists on dragging its feet with ...       0
# 13803  Who should replace Nikki Haley as our ambassad...       0
# 10583  Submit to those who lie continuously, to them ...       1
# 769    For me at least it was the key that opened the...       0
# 15668  Secret Gun Control Agenda Revealed: “three day...       1
# 1685   As far back as 1953, the CIA published an assa...       1
# 8322   The Obama administration approached two U.S. b...       0
# 16023  The first group of the migrant caravan arrived...       1
# 11111  The now well known McCarrick Villanova Speech ...       0
# 11363  Phone This field is for validation purposes an...       0
# 11636  But it does move in lockstep with the US on mu...       1
# 14423  The nominee and Republican senators used the o...       1
# 5578                         But we've seen that before.       1
# 4426   I see that many times in the Church, over and ...       0
# 13526                              Let’s hear from them.       0
# 466    And this after also humiliating Burke as the s...       0
# 6265   "Working with partners and responding early an...       0
# 5734   Why would Benedict take advice from a man like...       1
# 11284  “It’s not a call to action,” Mr. Giuliani said...       0
# 11964  I trust that the seminaries I choose, very dis...       1
# 5191   The commission was behind Francis’ decision in...       1
# 13418  She conveniently waited until this Sunday to c...       0
# 5390   Here are the six states where the legislatures...       0
# 860    He still has fever but has stopped vomiting; t...       0
# 15795  Do you want to kick in to our ‘war chest’ so t...       0
# 7270   Instead, move to a location where the sounds a...       0
#
# [13852 rows x 2 columns]

# %%
zerData = zerData.drop ([index for index in onesIndex],axis=0)
zerData
# Out:
#                                                 sentence  answer
# 1744        How did Warren resolve this troubling issue?       0
# 15532  To deal with the perceived threat the US has d...       0
# 7284   The unnamed US citizen assigned to the consula...       0
# 6388   All presidents since Clinton have crossed coun...       0
# 811    The White House also announced Monday that it ...       0
# 3656   To date, in addition to the three original sig...       0
# 3090   The priest would kiss the boys and grope them,...       0
# 5066                                       Advertisement       0
# 15458  It’s respecting the diversity that we have in ...       0
# 14951  In a series of tweets on Thursday, President T...       0
# 9045   A Muslima in the U.S. promoted the Islamic Sta...       0
# 3879   We need the Sacrifice of the Mass – not a meal...       0
# 15842  Democratic party leaders provided staffers wit...       0
# 9862   No matter your race, creed, ethnicity, sexual ...       0
# 12187  The emerging homosexual clergy scandal is just...       0
# 9980   War at the Top of the ... Eric Margolis Best P...       0
# 6550   That said, on average the disease kills around...       0
# 14100  Given that 36 years have passed since the inci...       0
# 15902  Do you agree with the call for a federal inves...       0
# 10046  The Byzantine scholar Bessarion wrote to the D...       0
# 15849  Despite barbed wires and thousands of troops o...       0
# 4639   The research starter on the SNHU’s Shapiro lib...       0
# 5155   “Absurd as it may sound the danger we face com...       0
# 7356   Ironically, even in doing this he is likely to...       0
# 11143  He lapped up the accolades from the secular cu...       0
# 11535                                           13:2-4).       0
# 5899                           From Greenwald’s article:       0
# 5350   Depending on an alien’s criminality, an alien ...       0
# 7600                        Federation: Italy - Lombardy       0
# 11948  It causes others to sin in their thoughts, wor...       0
# ...                                                  ...     ...
# 15835  Dems got voters to use altered forms to fix & ...       0
# 7849   From January to March of this year, our trade ...       0
# 2558                    “Is there a mini ice age coming?       0
# 8666   He stood up to challenge the fact that the CIA...       0
# 11096  Secretary of State Mike Pompeo was pressed abo...       0
# 13035  This has to also involve, as Gorka urges, “a n...       0
# 12309  And the Lord said, Because the cry of Sodom an...       0
# 3385   Haig spoke with investigators four times after...       0
# 4555                                             Related       0
# 1184   Subject to the receipt of further information,...       0
# 6420   It's due to sanctions imposed by the likes of ...       0
# 5311        “I think that was what they wanted to write.       0
# 2433   Gonzalez hails from McAllen, Texas, and attend...       0
# 6949   Keep these facts in mind as we read through th...       0
# 15773  If Congress insists on dragging its feet with ...       0
# 13803  Who should replace Nikki Haley as our ambassad...       0
# 769    For me at least it was the key that opened the...       0
# 8322   The Obama administration approached two U.S. b...       0
# 11111  The now well known McCarrick Villanova Speech ...       0
# 11363  Phone This field is for validation purposes an...       0
# 4426   I see that many times in the Church, over and ...       0
# 13526                              Let’s hear from them.       0
# 466    And this after also humiliating Burke as the s...       0
# 6265   "Working with partners and responding early an...       0
# 11284  “It’s not a call to action,” Mr. Giuliani said...       0
# 13418  She conveniently waited until this Sunday to c...       0
# 5390   Here are the six states where the legislatures...       0
# 860    He still has fever but has stopped vomiting; t...       0
# 15795  Do you want to kick in to our ‘war chest’ so t...       0
# 7270   Instead, move to a location where the sounds a...       0
#
# [9844 rows x 2 columns]

# %%
i = 0
while i < len(onesIndex):
    ones.append(1)
    i+=1

# %%
onesData = pd.DataFrame(line, columns = ['sentence'], index = onesIndex).join(pd.DataFrame(ones, columns = ['answer'], index = onesIndex))

# %%
onesData
# Out:
#                                                 sentence  answer
# 12811  - [And just two days ago, Archbishop Salvatore...       1
# 16282  That's what Columbia snowflakes thought was of...       1
# 13096  She noticed that Latino voters did record-brea...       1
# 10241                                   This was unjust.       1
# 15941  This massive Democrat voter fraud could be the...       1
# 7889   And Trump is president because he read the par...       1
# 15433   Assange never even considered fleeing to Russia.       1
# 9214   But what, Mr. Farage, are we to think about th...       1
# 8546   It’s the very reason the governments of the wo...       1
# 1844   The toxic environment is due almost exclusivel...       1
# 9003   Wills is no more trustworthy when he deals wit...       1
# 4604   Home damage in Puerto Rico, where the poverty ...       1
# 15687  Raise teacher’s pay to $50,000, that will neve...       1
# 12186  How inconvenient that since 2013 during Franci...       1
# 14536  "This country is being ripped apart here, and ...       1
# 9037   Wills’ peaceful fantasy Qur’an raises one mass...       1
# 12696  The Church, the depositary of the blessing of ...       1
# 13132  Meanwhile, according to a Breitbart report by ...       1
# 15610  They are predominantly young men, there are fe...       1
# 3058   Apparently His Holiness was informed that the ...       1
# 13299  In his “9 Steps” article, he points out that t...       1
# 3256           Seriously, it's been four months already!       1
# 2201   With a diameter of about 3 miles, the asteroid...       1
# 1579                   Weinandy had been given the boot.       1
# 3934                                      We don’t know.       1
# 2589   The Cardinal knows this is moral and canonical...       1
# 12011  Editor’s Note: Over the years, Bishop Robert M...       1
# 12879  When an apostolic visitation, compelled by mou...       1
# 4720   “And now, we’ve been able to make images farth...       1
# 970    Jeff then describes a scene in which he and hi...       1
# ...                                                  ...     ...
# 1021   Now he's whining that boycotting his play is a...       1
# 14541  Perhaps Arizona will put someone in that actua...       1
# 15787                                     He’ll be back.       1
# 7099   The other type is an "ultrasound" attack, wher...       1
# 7041   [5] I’d love to hear from some monastic superi...       1
# 2612   Francis and all his designs will ultimately co...       1
# 10253  No doubt, Finicum would have been found not gu...       1
# 10555  But if thou do that which is evil, be afraid; ...       1
# 8792   Special FBI agent Peter Stzrok and Lisa Page, ...       1
# 14502                          I hope you never get it.”       1
# 3890                                           No faith.       1
# 7734   The Ron Paul Curriculum provides students with...       1
# 1899   By now the whole Catholic world has heard of t...       1
# 2734   The bishops of the Catholic Church are much mo...       1
# 9167   In the year 718, the Umayyad caliph Umar ibn A...       1
# 2047   What must be most annoying for the Clinton tea...       1
# 9274   Katrin Axelsson and Lisa Longstaff of Women Ag...       1
# 15920  They may have believed that they were supplyin...       1
# 6396   I despise Islam and I despise the ideology of ...       1
# 5051   O’Malley, the archbishop of Boston, said in th...       1
# 10583  Submit to those who lie continuously, to them ...       1
# 15668  Secret Gun Control Agenda Revealed: “three day...       1
# 1685   As far back as 1953, the CIA published an assa...       1
# 16023  The first group of the migrant caravan arrived...       1
# 11636  But it does move in lockstep with the US on mu...       1
# 14423  The nominee and Republican senators used the o...       1
# 5578                         But we've seen that before.       1
# 5734   Why would Benedict take advice from a man like...       1
# 11964  I trust that the seminaries I choose, very dis...       1
# 5191   The commission was behind Francis’ decision in...       1
#
# [4008 rows x 2 columns]

# %%
with open('zerData.pkl', 'wb') as output_file: 
    pickle.dump(zerData, output_file, protocol=pickle.HIGHEST_PROTOCOL)
with open('onesData.pkl', 'wb') as output_file: 
    pickle.dump(onesData, output_file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('zerData.pkl', 'rb') as input_file: 
    zerData = pickle.load(input_file)
with open('onesData.pkl', 'rb') as input_file: 
    onesData = pickle.load(input_file)

# %%
DataParts = np.array_split(zerData, 5)

# %%
for DataPart in DataParts:
    print(pd.concat([DataPart,onesData], ignore_index=True))
# Out:
#                                                sentence  answer
# 0          How did Warren resolve this troubling issue?       0
# 1     To deal with the perceived threat the US has d...       0
# 2     The unnamed US citizen assigned to the consula...       0
# 3     All presidents since Clinton have crossed coun...       0
# 4     The White House also announced Monday that it ...       0
# 5     To date, in addition to the three original sig...       0
# 6     The priest would kiss the boys and grope them,...       0
# 7                                         Advertisement       0
# 8     It’s respecting the diversity that we have in ...       0
# 9     In a series of tweets on Thursday, President T...       0
# 10    A Muslima in the U.S. promoted the Islamic Sta...       0
# 11    We need the Sacrifice of the Mass – not a meal...       0
# 12    Democratic party leaders provided staffers wit...       0
# 13    No matter your race, creed, ethnicity, sexual ...       0
# 14    The emerging homosexual clergy scandal is just...       0
# 15    War at the Top of the ... Eric Margolis Best P...       0
# 16    That said, on average the disease kills around...       0
# 17    Given that 36 years have passed since the inci...       0
# 18    Do you agree with the call for a federal inves...       0
# 19    The Byzantine scholar Bessarion wrote to the D...       0
# 20    Despite barbed wires and thousands of troops o...       0
# 21    The research starter on the SNHU’s Shapiro lib...       0
# 22    “Absurd as it may sound the danger we face com...       0
# 23    Ironically, even in doing this he is likely to...       0
# 24    He lapped up the accolades from the secular cu...       0
# 25                                             13:2-4).       0
# 26                            From Greenwald’s article:       0
# 27    Depending on an alien’s criminality, an alien ...       0
# 28                         Federation: Italy - Lombardy       0
# 29    It causes others to sin in their thoughts, wor...       0
# ...                                                 ...     ...
# 5947  Now he's whining that boycotting his play is a...       1
# 5948  Perhaps Arizona will put someone in that actua...       1
# 5949                                     He’ll be back.       1
# 5950  The other type is an "ultrasound" attack, wher...       1
# 5951  [5] I’d love to hear from some monastic superi...       1
# 5952  Francis and all his designs will ultimately co...       1
# 5953  No doubt, Finicum would have been found not gu...       1
# 5954  But if thou do that which is evil, be afraid; ...       1
# 5955  Special FBI agent Peter Stzrok and Lisa Page, ...       1
# 5956                          I hope you never get it.”       1
# 5957                                          No faith.       1
# 5958  The Ron Paul Curriculum provides students with...       1
# 5959  By now the whole Catholic world has heard of t...       1
# 5960  The bishops of the Catholic Church are much mo...       1
# 5961  In the year 718, the Umayyad caliph Umar ibn A...       1
# 5962  What must be most annoying for the Clinton tea...       1
# 5963  Katrin Axelsson and Lisa Longstaff of Women Ag...       1
# 5964  They may have believed that they were supplyin...       1
# 5965  I despise Islam and I despise the ideology of ...       1
# 5966  O’Malley, the archbishop of Boston, said in th...       1
# 5967  Submit to those who lie continuously, to them ...       1
# 5968  Secret Gun Control Agenda Revealed: “three day...       1
# 5969  As far back as 1953, the CIA published an assa...       1
# 5970  The first group of the migrant caravan arrived...       1
# 5971  But it does move in lockstep with the US on mu...       1
# 5972  The nominee and Republican senators used the o...       1
# 5973                        But we've seen that before.       1
# 5974  Why would Benedict take advice from a man like...       1
# 5975  I trust that the seminaries I choose, very dis...       1
# 5976  The commission was behind Francis’ decision in...       1
#
# [5977 rows x 2 columns]
#                                                sentence  answer
# 0                                              Harding?       0
# 1     “What is the relationship between Christ and S...       0
# 2     You also agree to this site's Privacy Policy a...       0
# 3     Who should replace Nikki Haley as our ambassad...       0
# 4     “Senior U.S. government officials repeatedly t...       0
# 5     Let’s stop lamenting and start doing practical...       0
# 6     Daniel Greenfield, a Shillman Journalism Fello...       0
# 7     Over the past few weeks, the active-duty servi...       0
# 8     They also called me by phone in Melbourne to s...       0
# 9                                                  Why?       0
# 10    Weinandy is a “man of the Council” and a promi...       0
# 11    Nor does the UK admit only preachers of jihad ...       0
# 12    To be a refuge for sinners (which we should be...       0
# 13    Yet Mr. Horowitz saw no reason to doubt the si...       0
# 14                    He can bring Julian Assange home.       0
# 15                                      By Marton Dunai       0
# 16                          Laws are for conservatives.       0
# 17    He tried to continue speaking until his mic wa...       0
# 18    The world has not compromised—its spirit is ex...       0
# 19                                              Email *       0
# 20    The left-wing curriculum and common core are a...       0
# 21    The high court normally has a complement of ni...       0
# 22    A large percentage of Latino voters in Florida...       0
# 23    Whom do you consider to be the most corrupt De...       0
# 24                                          RT reports:       0
# 25     And the U.S. military will stand behind the BSF.       0
# 26    The conference is advocating measures to stren...       0
# 27                                        In this time!       0
# 28    It's unknown whether the ammunition Haig sold ...       0
# 29    In a speech he gave at Darul Uloom, in August ...       0
# ...                                                 ...     ...
# 5947  Now he's whining that boycotting his play is a...       1
# 5948  Perhaps Arizona will put someone in that actua...       1
# 5949                                     He’ll be back.       1
# 5950  The other type is an "ultrasound" attack, wher...       1
# 5951  [5] I’d love to hear from some monastic superi...       1
# 5952  Francis and all his designs will ultimately co...       1
# 5953  No doubt, Finicum would have been found not gu...       1
# 5954  But if thou do that which is evil, be afraid; ...       1
# 5955  Special FBI agent Peter Stzrok and Lisa Page, ...       1
# 5956                          I hope you never get it.”       1
# 5957                                          No faith.       1
# 5958  The Ron Paul Curriculum provides students with...       1
# 5959  By now the whole Catholic world has heard of t...       1
# 5960  The bishops of the Catholic Church are much mo...       1
# 5961  In the year 718, the Umayyad caliph Umar ibn A...       1
# 5962  What must be most annoying for the Clinton tea...       1
# 5963  Katrin Axelsson and Lisa Longstaff of Women Ag...       1
# 5964  They may have believed that they were supplyin...       1
# 5965  I despise Islam and I despise the ideology of ...       1
# 5966  O’Malley, the archbishop of Boston, said in th...       1
# 5967  Submit to those who lie continuously, to them ...       1
# 5968  Secret Gun Control Agenda Revealed: “three day...       1
# 5969  As far back as 1953, the CIA published an assa...       1
# 5970  The first group of the migrant caravan arrived...       1
# 5971  But it does move in lockstep with the US on mu...       1
# 5972  The nominee and Republican senators used the o...       1
# 5973                        But we've seen that before.       1
# 5974  Why would Benedict take advice from a man like...       1
# 5975  I trust that the seminaries I choose, very dis...       1
# 5976  The commission was behind Francis’ decision in...       1
#
# [5977 rows x 2 columns]
#                                                sentence  answer
# 0     “The blessing expresses that one is welcomed b...       0
# 1     After joining the militant group, he agreed to...       0
# 2     “This is a major development in the outbreak,”...       0
# 3     Finally, the autonomous Carmels have asked hel...       0
# 4     If it is ever necessary to hold back the revol...       0
# 5     Below are the 14 profiles currently listed as ...       0
# 6     There may be a few gestures of disarmament but...       0
# 7     I hear the number the FBI informant is much, m...       0
# 8                                         As it had to.       0
# 9     Of course, RINO Senator Jeff Flake (R-AZ) want...       0
# 10    And if you are unchastely propositioned, abuse...       0
# 11    Mr. Horowitz wrote that this exchange was “not...       0
# 12    But “family member” is defined to include “for...       0
# 13                              Reprinted from WND.com.       0
# 14    During the Myers controversy, the Center took ...       0
# 15    We can say that [these bad changes are] not in...       0
# 16    Maybe Trump has some more concessions up his s...       0
# 17    This would explain why he will not a “say a wo...       0
# 18    “These are the stories that we know,” Gillum s...       0
# 19    A Nevada judge on Tuesday unsealed police sear...       0
# 20    I would be surprised now if we were not see mo...       0
# 21    Welcome to the dumbing down of the Catholic Fa...       0
# 22                                              24:16).       0
# 23    Like the Dubia cardinals, he said he made it p...       0
# 24    Lagging well in the rear were such staples, no...       0
# 25                      CARTER: I believe that is true.       0
# 26                                      in formation: 8       0
# 27    “You ain’t supporting s--- n----!” the man is ...       0
# 28    Ebola virus disease, which most commonly affec...       0
# 29                take our poll - story continues below       0
# ...                                                 ...     ...
# 5947  Now he's whining that boycotting his play is a...       1
# 5948  Perhaps Arizona will put someone in that actua...       1
# 5949                                     He’ll be back.       1
# 5950  The other type is an "ultrasound" attack, wher...       1
# 5951  [5] I’d love to hear from some monastic superi...       1
# 5952  Francis and all his designs will ultimately co...       1
# 5953  No doubt, Finicum would have been found not gu...       1
# 5954  But if thou do that which is evil, be afraid; ...       1
# 5955  Special FBI agent Peter Stzrok and Lisa Page, ...       1
# 5956                          I hope you never get it.”       1
# 5957                                          No faith.       1
# 5958  The Ron Paul Curriculum provides students with...       1
# 5959  By now the whole Catholic world has heard of t...       1
# 5960  The bishops of the Catholic Church are much mo...       1
# 5961  In the year 718, the Umayyad caliph Umar ibn A...       1
# 5962  What must be most annoying for the Clinton tea...       1
# 5963  Katrin Axelsson and Lisa Longstaff of Women Ag...       1
# 5964  They may have believed that they were supplyin...       1
# 5965  I despise Islam and I despise the ideology of ...       1
# 5966  O’Malley, the archbishop of Boston, said in th...       1
# 5967  Submit to those who lie continuously, to them ...       1
# 5968  Secret Gun Control Agenda Revealed: “three day...       1
# 5969  As far back as 1953, the CIA published an assa...       1
# 5970  The first group of the migrant caravan arrived...       1
# 5971  But it does move in lockstep with the US on mu...       1
# 5972  The nominee and Republican senators used the o...       1
# 5973                        But we've seen that before.       1
# 5974  Why would Benedict take advice from a man like...       1
# 5975  I trust that the seminaries I choose, very dis...       1
# 5976  The commission was behind Francis’ decision in...       1
#
# [5977 rows x 2 columns]
#                                                sentence  answer
# 0                           Election Day is November 6.       0
# 1                 * Yes, military force should be used.       0
# 2     Nonetheless there have not been amalgamations ...       0
# 3     On Friday, former Puerto Rican Governor Alejan...       0
# 4     remember how CAIR advised Muslims not to talk ...       0
# 5     Three days later the same checkpoint snared an...       0
# 6     In his opening remarks, Douthat laid out three...       0
# 7        Chris Ferrara to Robert Fastiggi • 9 hours ago       0
# 8     Name This field is for validation purposes and...       0
# 9               Now how does Farage propose to do that?       0
# 10                                        By Nick Brown       0
# 11                                       Murillo wrote:       0
# 12    Norris-Weeks said she saw an early draft of th...       0
# 13    But my own sickness at the stories is quickly ...       0
# 14    We have seen a similar pattern in the Skripal ...       0
# 15    Many in the hierarchy were active homosexuals ...       0
# 16    Will Brett Kavanaugh be confirmed to the Supre...       0
# 17    She has told her class that if they had questi...       0
# 18    However, upon learning of his behavior the loc...       0
# 19    And the Pope is almost certain to ignore this ...       0
# 20                                       Ratzinger: “…”       0
# 21    Daniel Greenfield said this about Dina Habib P...       0
# 22                       He retweeted authentic videos.       0
# 23                                    Los Angeles Times       0
# 24    Court documents say Patel lied about his trave...       0
# 25    Immigrants held 16.99% of total jobs in Decemb...       0
# 26    Bill Maher, for whatever unappealing drawbacks...       0
# 27                                       CARTER: It is.       0
# 28    And all they say is “Obedience, obedience, obe...       0
# 29                      The Best of Jacob G. Hornberger       0
# ...                                                 ...     ...
# 5947  Now he's whining that boycotting his play is a...       1
# 5948  Perhaps Arizona will put someone in that actua...       1
# 5949                                     He’ll be back.       1
# 5950  The other type is an "ultrasound" attack, wher...       1
# 5951  [5] I’d love to hear from some monastic superi...       1
# 5952  Francis and all his designs will ultimately co...       1
# 5953  No doubt, Finicum would have been found not gu...       1
# 5954  But if thou do that which is evil, be afraid; ...       1
# 5955  Special FBI agent Peter Stzrok and Lisa Page, ...       1
# 5956                          I hope you never get it.”       1
# 5957                                          No faith.       1
# 5958  The Ron Paul Curriculum provides students with...       1
# 5959  By now the whole Catholic world has heard of t...       1
# 5960  The bishops of the Catholic Church are much mo...       1
# 5961  In the year 718, the Umayyad caliph Umar ibn A...       1
# 5962  What must be most annoying for the Clinton tea...       1
# 5963  Katrin Axelsson and Lisa Longstaff of Women Ag...       1
# 5964  They may have believed that they were supplyin...       1
# 5965  I despise Islam and I despise the ideology of ...       1
# 5966  O’Malley, the archbishop of Boston, said in th...       1
# 5967  Submit to those who lie continuously, to them ...       1
# 5968  Secret Gun Control Agenda Revealed: “three day...       1
# 5969  As far back as 1953, the CIA published an assa...       1
# 5970  The first group of the migrant caravan arrived...       1
# 5971  But it does move in lockstep with the US on mu...       1
# 5972  The nominee and Republican senators used the o...       1
# 5973                        But we've seen that before.       1
# 5974  Why would Benedict take advice from a man like...       1
# 5975  I trust that the seminaries I choose, very dis...       1
# 5976  The commission was behind Francis’ decision in...       1
#
# [5977 rows x 2 columns]
#                                                sentence  answer
# 0     Let’s remember that this comes from the Congre...       0
# 1     After I got saved, as they say (John 3:3), I r...       0
# 2     Moreover, by her own admission to the Washingt...       0
# 3     Pennsylvania’s Supreme Court ruled last month ...       0
# 4     The remarks represent the first time senior Ir...       0
# 5     During the confessional, a Canadian man by the...       0
# 6                 * Yes, he should have gotten it back.       0
# 7     Congressional Republicans are hoping the files...       0
# 8     The email was forwarded to Google vice preside...       0
# 9     On the morning of Thursday, June 20, 2013, I w...       0
# 10    Also, if you’ve been hurt by a priest of our d...       0
# 11    Powell already lives in New York, where the U....       0
# 12    At HotAir.com John Sexton explains the importa...       0
# 13    “Incapacity”… Where had I heard that language ...       0
# 14    Mobile lab materials being shipped to strength...       0
# 15    Most of the aliens targeted by ERO deportation...       0
# 16     Giáp claimed that the attack had been imaginary.       0
# 17    When we confess our sins and we truly say, “I ...       0
# 18    One way or another, the Church will have to re...       0
# 19    Dawn Eden Goldstein, S.T.D., professor of Dogm...       0
# 20    If this growth rate persists, it portends a do...       0
# 21    However, the totality of the evidence points t...       0
# 22    The emails were first revealed on Fox News on ...       0
# 23                     McCarrick, Pineda/Maradiaga, Fr.       0
# 24    The New York Times could not find a single per...       0
# 25    Nigel Farage Warns “We’ll Lose” A Battle Betwe...       0
# 26    John Pilger: His state of health is just about...       0
# 27                                        He has to go.       0
# 28    This could be a great mercy for them as well a...       0
# 29    The site says that “in addition to Bergoglio’s...       0
# ...                                                 ...     ...
# 5946  Now he's whining that boycotting his play is a...       1
# 5947  Perhaps Arizona will put someone in that actua...       1
# 5948                                     He’ll be back.       1
# 5949  The other type is an "ultrasound" attack, wher...       1
# 5950  [5] I’d love to hear from some monastic superi...       1
# 5951  Francis and all his designs will ultimately co...       1
# 5952  No doubt, Finicum would have been found not gu...       1
# 5953  But if thou do that which is evil, be afraid; ...       1
# 5954  Special FBI agent Peter Stzrok and Lisa Page, ...       1
# 5955                          I hope you never get it.”       1
# 5956                                          No faith.       1
# 5957  The Ron Paul Curriculum provides students with...       1
# 5958  By now the whole Catholic world has heard of t...       1
# 5959  The bishops of the Catholic Church are much mo...       1
# 5960  In the year 718, the Umayyad caliph Umar ibn A...       1
# 5961  What must be most annoying for the Clinton tea...       1
# 5962  Katrin Axelsson and Lisa Longstaff of Women Ag...       1
# 5963  They may have believed that they were supplyin...       1
# 5964  I despise Islam and I despise the ideology of ...       1
# 5965  O’Malley, the archbishop of Boston, said in th...       1
# 5966  Submit to those who lie continuously, to them ...       1
# 5967  Secret Gun Control Agenda Revealed: “three day...       1
# 5968  As far back as 1953, the CIA published an assa...       1
# 5969  The first group of the migrant caravan arrived...       1
# 5970  But it does move in lockstep with the US on mu...       1
# 5971  The nominee and Republican senators used the o...       1
# 5972                        But we've seen that before.       1
# 5973  Why would Benedict take advice from a man like...       1
# 5974  I trust that the seminaries I choose, very dis...       1
# 5975  The commission was behind Francis’ decision in...       1
#
# [5976 rows x 2 columns]

# %%
DataParts[0]
# Out:
#                                                 sentence  answer
# 1744        How did Warren resolve this troubling issue?       0
# 15532  To deal with the perceived threat the US has d...       0
# 7284   The unnamed US citizen assigned to the consula...       0
# 6388   All presidents since Clinton have crossed coun...       0
# 811    The White House also announced Monday that it ...       0
# 3656   To date, in addition to the three original sig...       0
# 3090   The priest would kiss the boys and grope them,...       0
# 5066                                       Advertisement       0
# 15458  It’s respecting the diversity that we have in ...       0
# 14951  In a series of tweets on Thursday, President T...       0
# 9045   A Muslima in the U.S. promoted the Islamic Sta...       0
# 3879   We need the Sacrifice of the Mass – not a meal...       0
# 15842  Democratic party leaders provided staffers wit...       0
# 9862   No matter your race, creed, ethnicity, sexual ...       0
# 12187  The emerging homosexual clergy scandal is just...       0
# 9980   War at the Top of the ... Eric Margolis Best P...       0
# 6550   That said, on average the disease kills around...       0
# 14100  Given that 36 years have passed since the inci...       0
# 15902  Do you agree with the call for a federal inves...       0
# 10046  The Byzantine scholar Bessarion wrote to the D...       0
# 15849  Despite barbed wires and thousands of troops o...       0
# 4639   The research starter on the SNHU’s Shapiro lib...       0
# 5155   “Absurd as it may sound the danger we face com...       0
# 7356   Ironically, even in doing this he is likely to...       0
# 11143  He lapped up the accolades from the secular cu...       0
# 11535                                           13:2-4).       0
# 5899                           From Greenwald’s article:       0
# 5350   Depending on an alien’s criminality, an alien ...       0
# 7600                        Federation: Italy - Lombardy       0
# 11948  It causes others to sin in their thoughts, wor...       0
# ...                                                  ...     ...
# 11731       Pope John Paul certainly didn't accept that.       0
# 2893   Reports indicated that some jihadis were payin...       0
# 16029  Border security is national security, and @DHS...       0
# 11009  Completing this poll grants you access to Free...       0
# 5168   “We don’t think the fight is hopeless, on the ...       0
# 4091   Since I began this work six years ago, now, I ...       0
# 10673  And he saith unto him, Cast thy garment about ...       0
# 2888             None of this is really that surprising.       0
# 7529                              number of convents: 14       0
# 13410  According to Breitbart, on Friday, 65 women fr...       0
# 6505   The paper suggests that the US focus on Iran’s...       0
# 16140  If you appreciated it, or any of the others, p...       0
# 13404  Kavanaugh’s friend, who has not been identifie...       0
# 1406   Why not extend the secrecy for another 25 year...       0
# 7507   But in this situation, the “solution” undertak...       0
# 14378  According to Kavanaugh, the Fourth Amendment a...       0
# 8457   Wasserman Schultz did not respond to a request...       0
# 1811                            What good would that do?       0
# 14855  Speaking in Ankara, Turkey, Pompeo offered tha...       0
# 9621   The Auschwitz camp, which is in southern Polan...       0
# 12005                      Faithfully yours in the Lord,       0
# 9575   Whom do you consider to be the most corrupt De...       0
# 10995  Leftwing journalist Glenn Greenwald is no fan ...       0
# 12961  As to Bertone and Sodano, Viganò provides furt...       0
# 5180   When he created the commission, Francis said: ...       0
# 11572  But they raised it in a way that didn’t suppor...       0
# 1486   … The department said Khweis used encrypted de...       0
# 6027   Kazi had lived in the Bay Area, including Saus...       0
# 10221                            Trump Pardons Hammonds!       0
# 774    It should be clear by now that the entire offi...       0
#
# [1969 rows x 2 columns]

# %%
vec_train_x=Create_vectors(X_train, Positions, Tf_idf)
# Out:
# Vectorization in progress:
# 13852/13852

# %%
vec_test_x=Create_vectors(X_test, Positions, Tf_idf)
# Out:
# Vectorization in progress:
# 2445/2445

# %%
# knn = KNeighborsClassifier()

# grid=GridSearchCV(knn, param_grid={'Data': Data['sentence']})
# grid.fit(vec_train_x, Y_train)

# %%
with open('X_train.pkl', 'wb') as output_file: 
    pickle.dump(vec_train_x, output_file, protocol=pickle.HIGHEST_PROTOCOL)
with open('X_test.pkl', 'wb') as output_file: 
    pickle.dump(vec_test_x, output_file, protocol=pickle.HIGHEST_PROTOCOL)
with open('Y_train.pkl', 'wb') as output_file: 
    pickle.dump(Y_train, output_file, protocol=pickle.HIGHEST_PROTOCOL)
with open('Y_test.pkl', 'wb') as output_file: 
    pickle.dump(Y_test, output_file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
clasas = xgb.XGBClassifier(max_depth = 10, n_estimators =1000)
clasas.fit(np.array(vec_train_x),np.array(Y_train))
clasas.score(np.array(vec_test_x),np.array(Y_test))
# Out:
# 0.7132924335378323

# %%
print(classification_report(clasas.predict(vec_test_x), Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.76      0.81      1999
#            1       0.32      0.51      0.40       446
#
#    micro avg       0.71      0.71      0.71      2445
#    macro avg       0.60      0.64      0.60      2445
# weighted avg       0.77      0.71      0.74      2445

# %%
#import svm
#model = svm.svc(parameters)
#rbf(C = 3), линейная модель
#разделить выборку на 5 выборок, в каждой из которых 1/5 нулей и все единицы (см. код с хакатона)
#подготовить данные FLC
#ОБУЧИТЬ МОДЕЛЬ (FIT)
#ПРОВЕРИТЬ КАЧЕСТВО (score)
#classification_report
model = svm.SVC(C = 0.5,gamma = 'scale')
#grid=GridSearchCV(model, param_grid={'Sentence': Data['sentence'],'Answer': Data['answer']})
model.fit(X = (vec_train_x+vec_test_x),y = (list(Y_train)+list(Y_test)))
# Out:
# SVC(C=0.5, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
model.score(vec_train_x+vec_test_x, list(Y_train)+list(Y_test))
# Out:
# 0.7252255016260661

# %%
print(classification_report(model.predict(vec_train_x+vec_test_x), list(Y_train)+list(Y_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.74      0.83     14824
#            1       0.18      0.58      0.28      1473
#
#    micro avg       0.73      0.73      0.73     16297
#    macro avg       0.56      0.66      0.55     16297
# weighted avg       0.88      0.73      0.78     16297
